# %% [markdown]
# #   $$                         Mean     $$

# %% [markdown]
# ![images.png](attachment:images.png)

# %% [markdown]
# * The Mean or average is probably the most commonly used method of describing central tendency.
# * To compute the mean all you do is add up all the values and divide by the number of values.
# * For example, the mean or average quiz score is determined by summing all the scores and dividing by the number of students taking the exam.
# * For example, consider the test score values:
#   15, 20, 21, 20, 36, 15, 25, 15
# * The sum of these 8 values is 167, so the mean is 167/8 = 20.875.

# %% [markdown]
# ![mean%20formula.png](attachment:mean%20formula.png)

# %%
def mean_of_list(l):
  total = 0
  for val in l:
    total = total + val
  return total

my_list = [1, 3, 4, 5, 7, 9, 2]
print ("The sum of my_list is", mean_of_list(my_list))
# Out:
# The sum of my_list is 31

# %% [markdown]
# #  $$Median$$

# %% [markdown]
# ![median.png](attachment:median.png)

# %% [markdown]
# * The Median is the score found at the exact middle of the set of values.
# * One way to compute the median is to list all scores in numerical order, and then locate the score in the center of the sample. For example, if there are 500 scores in the list, score #250 would be the median.
# * If we order the 8 scores shown above, we would get:
# * 15, 15, 15, 20, 20, 21, 25, 36
# * There are 8 scores and score #4 and #5 represent the halfway point. Since both of these scores are 20, the median is 20.

# %% [markdown]
# ![median%20formula.png](attachment:median%20formula.png)

# %%
n_num = [15, 15, 15, 20, 20, 21, 25, 36] 
n = len(n_num) 
n_num.sort() 
  
if n % 2 == 0: 
    median1 = n_num[n//2] 
    median2 = n_num[n//2 - 1] 
    median = (median1 + median2)/2
else: 
    median = n_num[n//2] 
print("Median is: " + str(median))
# Out:
# Median is: 20.0

# %% [markdown]
# # $$ Mode$$

# %% [markdown]
# ![mode.png](attachment:mode.png)

# %% [markdown]
# * The Mode is the most frequently occurring value in the set of scores. To determine the mode, you might again order the scores as shown above, and then count each one.
# * The most frequently occurring value is the mode. In our example, the value 15 occurs three times and is the model. In some distributions there is more than one modal value.
# * For instance, in a bimodal distribution there are two values that occur most frequently.

# %% [markdown]
# ![mode%20formula.png](attachment:mode%20formula.png)

# %%
from collections import Counter 

n_num = [1, 2, 3, 4, 5, 5] 
n = len(n_num) 
  
data = Counter(n_num) 
get_mode = dict(data) 
mode = [k for k, v in get_mode.items() if v == max(list(data.values()))] 
  
if len(mode) == n: 
    get_mode = "No mode found"
else: 
    get_mode = "Mode is / are: " + ', '.join(map(str, mode)) 
      
print(get_mode)
# Out:
# Mode is / are: 5

# %% [markdown]
# ![mmm.png](attachment:mmm.png)

# %% [markdown]
# #  $$Variance$$

# %% [markdown]
# ![Variance.png](attachment:Variance.png)

# %% [markdown]
# * Variance is an error from sensitivity to small fluctuations in the training set. High variance can cause an algorithm to model the random noise in the training data, rather than the intended output.
# * Variance potraits that how far the numbers are spread from the mean

# %% [markdown]
# ![Variance%20formula.png](attachment:Variance%20formula.png)

# %%
 def variance(data):
...     # Number of observations
...     n = len(data)
...     # Mean of the data
...     mean = sum(data) / n
...     # Square deviations
...     deviations = [(x - mean) ** 2 for x in data]
...     # Variance
...     variance = sum(deviations) / n
...     return variance
...

# %%
variance([4, 8, 6, 5, 3, 2, 8, 9, 2, 5])
# Out:
# 5.76

# %% [markdown]
# #  $$Standard Deviation$$

# %% [markdown]
# * The standard deviation is a statistic that measures the dispersion of a dataset relative to its mean and is calculated as the square root of the variance.
# * If the data points are further from the mean, there is a higher deviation within the data set; thus, the more spread out the data, the higher the standard deviation.
# * Standard deviation measures the dispersion of a dataset relative to its mean.
# * As a downside, the standard deviation calculates all uncertainty as risk, even when it’s in the investor's favor—such as above average returns.

# %% [markdown]
# ![standard%20deviation.png](attachment:standard%20deviation.png)

# %% [markdown]
# ![download.png](attachment:download.png)

# %%
def sd(d): 
    n = len(d) 
 
    if n <= 1: 
        return 0.0 
 
    mean, sd = avg(d), 0.0 
 
    #For calculating standard deviation 
    for i in data: 
        sd += (float(i) - mean)**2 
    sd = math.sqrt(sd / float(n-1)) 
 
    return sd 
 
def avg(l): 
    n, mean = len(l), 0.0 
 
    if n <= 1: 
        return ls[0] 
 
    #For calculating average 
    for i in l: 
        mean+=float(i) 
    mean/=float(n) 
 
    return mean 
 
a = [11,5,2,8,7] 
print('Sample Data--> ',*a) 
print('Standard Deviation--> ',sd(a))

# %% [markdown]
# # $$Correlation$$

# %% [markdown]
# * Correlation is a measure of how strongly one varible depends on another
# * Correlation can be an important tool for feature engineering in machine learning
# * Correlation is Positive when the values increase together, and
# * Correlation is Negative when one value decreases as the other increases

# %% [markdown]
# ![correlation%20formula.png](attachment:correlation%20formula.png)

# %% [markdown]
# ![images.jfif](attachment:images.jfif)

# %% [markdown]
# # $$Normal Distribution$$

# %% [markdown]
# ![normal%20distribution.png](attachment:normal%20distribution.png)

# %% [markdown]
# * Normal distribution also known as the Gaussian distribution, is a probability distribution that is symmetric about the mean, showing that data near the mean are more frequent in occurrence than data far from the mean.
# * In graph form, normal distribution will appear as a bell curve.
# * A normal distribution is the proper term for a probability bell curve.
# * In a normal distribution the mean is zero and the standard deviation is 1. It has zero skew and a kurtosis of 3.
# * Normal distributions are symmetrical, but not all symmetrical distributions are normal.
# * In reality, most pricing distributions are not perfectly normal.

# %% [markdown]
# ![normal%20distribution%20formula.png](attachment:normal%20distribution%20formula.png)

# %%
def normalization_f(a):
    maximum=max(a)
    minimum=min(a)
    norm_list=[]
    for i in a:
        value=(i-minimum)/(maximum-minimum)
        norm_list.append(value)
    return(norm_list)

# %% [markdown]
#  $$Skewness$$

# %% [markdown]
# ![skewness%20formula.png](attachment:skewness%20formula.png)

# %% [markdown]
# * Skewness is the measure of the asymmetry of an ideally symmetric probability distribution and is given by the third standardized moment. If that sounds way too complex, don’t worry! Let me break it down for you.

# %% [markdown]
#  * the normal distribution is the probability distribution without any skewness. You can look at the image below which shows symmetrical distribution that’s basically a normal distribution and you can see that it is symmetrical on both sides of the dashed line. Apart from this, there are two types of skewness:
#
# * Positive Skewness
# * Negative Skewness

# %% [markdown]
# ![skewness.png](attachment:skewness.png)
