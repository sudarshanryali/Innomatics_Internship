# %% [markdown]
# # Importing required libraries

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
import tensorflow as tf

# %% [markdown]
# # Loading the dataset

# %%
from keras.datasets import cifar10
from keras.utils.np_utils import to_categorical   


(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# ...
# 170500096/170498071 [==============================] - 2s 0us/step

# %% [markdown]
# # Visuaizing some images

# %%
for i in range(6):
  plt.imshow(X_train[i])
  plt.show()

# %%
print("Shape of training data:")
print(X_train.shape)
print(y_train.shape)
print("Shape of test data:")
print(X_test.shape)
print(y_test.shape)
print(X_train.ndim)
# Out:
# Shape of training data:
# (50000, 32, 32, 3)
# (50000, 1)
# Shape of test data:
# (10000, 32, 32, 3)
# (10000, 1)
# 4

# %%
X_train=X_train/255.0
X_test=X_test/255.0

# %% [markdown]
# # **Training the neural network model**

# %% [markdown]
# # **Using Optimiser SGD**

# %% [markdown]
# # **Experiment1:** Build a simple network with 2 dense layers

# %%
# Building 2 Layer ANN model
model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(32,32,3)),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(10,activation='sigmoid')
])

# %%
#compiling the model...
model.compile(optimizer="SGD" ,loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
#training data to the model...
model.fit(X_train,y_train,epochs=35)
# Out:
# Epoch 1/35
# 1563/1563 [==============================] - 7s 3ms/step - loss: 2.0530 - accuracy: 0.2530
# Epoch 2/35
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.7417 - accuracy: 0.3770
# Epoch 3/35
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.6526 - accuracy: 0.4108
# Epoch 4/35
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.5955 - accuracy: 0.4342
# Epoch 5/35
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.5478 - accuracy: 0.4494
# Epoch 6/35
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.5149 - accuracy: 0.4637
# Epoch 7/35
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.4712 - accuracy: 0.4805
# Epoch 8/35
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.4527 - accuracy: 0.4830
# Epoch 9/35
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.4280 - accuracy: 0.4925
# Epoch 10/35
# ...

# %%
#evaluating the model for testing data..
test_loss,test_acc=model.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.3708 - accuracy: 0.5236

# %%
model.metrics_names
# Out:
# ['loss', 'accuracy']

# %%
print("Test accuracy:",test_acc)
# Out:
# Test accuracy: 0.5235999822616577

# %% [markdown]
# # Using Optimiser ADAM

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(32,32,3)),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(10,activation='softmax')
])
#compiling the model...
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

#training data to the model...
model.fit(X_train,y_train,epochs=35)

#evaluating the model for testing data..
test_loss,test_acc=model.evaluate(X_test,y_test)
# Out:
# Epoch 1/35
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.9828 - accuracy: 0.2807
# Epoch 2/35
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7073 - accuracy: 0.3897
# Epoch 3/35
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6328 - accuracy: 0.4156
# Epoch 4/35
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5820 - accuracy: 0.4362
# Epoch 5/35
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5550 - accuracy: 0.4414
# Epoch 6/35
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5137 - accuracy: 0.4564
# Epoch 7/35
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5008 - accuracy: 0.4613
# Epoch 8/35
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.4938 - accuracy: 0.4608
# Epoch 9/35
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.4703 - accuracy: 0.4724
# Epoch 10/35
# ...

# %%
print("Test accuracy:",test_acc)
# Out:
# Test accuracy: 0.46630001068115234

# %% [markdown]
# # change the learning rates

# %%
# after adding learning rate

# %%
from keras.optimizers import SGD
sgd = SGD(lr=0.01)

model.compile(optimizer=sgd,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
#training data to the model...
model.fit(X_train,y_train,epochs=35)
# Out:
# Epoch 1/35
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.2556 - accuracy: 0.5521
# Epoch 2/35
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.2400 - accuracy: 0.5547
# Epoch 3/35
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.2425 - accuracy: 0.5536
# Epoch 4/35
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.2300 - accuracy: 0.5587
# Epoch 5/35
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.2362 - accuracy: 0.5540
# Epoch 6/35
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.2247 - accuracy: 0.5604
# Epoch 7/35
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.2331 - accuracy: 0.5587
# Epoch 8/35
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.2314 - accuracy: 0.5596
# Epoch 9/35
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.2271 - accuracy: 0.5573
# Epoch 10/35
# ...

# %%
#evaluating the model for testing data..
test_loss,test_acc=model.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.4712 - accuracy: 0.4886

# %%
print("Test accuracy:",test_acc)
# Out:
# Test accuracy: 0.4885999858379364

# %%
model=tf.keras.Sequential([
      tf.keras.layers.Flatten(input_shape=(32,32,3)),
      tf.keras.layers.Dense(128,activation='relu'),
      tf.keras.layers.Dense(128,activation='relu'),
      tf.keras.layers.Dense(10,activation='softmax')
])

# %%
#compiling the model...
sgd = SGD(lr=0.001) # learning rate = 0.001

model.compile(optimizer=sgd,
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
    
#training data to the model...
plotlr=model.fit(X_train,y_train,epochs=15, validation_split=0.2)

#evaluating the model for testing data..
test_losslr,test_acclr=model.evaluate(X_test,y_test)
print("Test accuracy:",test_acclr)
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 2.2098 - accuracy: 0.1883 - val_loss: 2.0274 - val_accuracy: 0.2795
# Epoch 2/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.9853 - accuracy: 0.2965 - val_loss: 1.9338 - val_accuracy: 0.3212
# Epoch 3/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.9097 - accuracy: 0.3280 - val_loss: 1.8926 - val_accuracy: 0.3385
# Epoch 4/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.8624 - accuracy: 0.3507 - val_loss: 1.8579 - val_accuracy: 0.3516
# Epoch 5/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.8364 - accuracy: 0.3573 - val_loss: 1.8265 - val_accuracy: 0.3597
# Epoch 6/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.7879 - accuracy: 0.3741 - val_loss: 1.8049 - val_accuracy: 0.3690
# Epoch 7/15
# ...

# %%
# defining a function for visualizing the loss and accuracy
def plotloss(plot):  
    plt.plot(plot.history['loss'])
    plt.plot(plot.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='best')
    plt.show()

# %%
def plotacc(plot):  
    plt.plot(plot.history['accuracy'])
    plt.plot(plot.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='best')
    plt.show()

# %%
plotloss(plotlr) # graph for loss
plotacc(plotlr)  # graph for accuracy

# %% [markdown]
# # **Experiment2:** Increase the dense layer by 2 with changing activations functions (‘selu’, ’softplus’, ’elu’, ’relu’)

# %% [markdown]
# # Increasing more 2 layers

# %% [markdown]
# # SELU
# <span style="color: red">SELU</span>

# %%
# Building 4 layer ANN
model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(32,32,3)),
    tf.keras.layers.Dense(128,activation='selu'),
    tf.keras.layers.Dense(128,activation='selu'),
    tf.keras.layers.Dense(128,activation='selu'),
    tf.keras.layers.Dense(128,activation='selu'),
    tf.keras.layers.Dense(10,activation='sigmoid')
])
#compiling the model...
model.compile(loss='sparse_categorical_crossentropy',metrics=['accuracy'])

#training data to the model...
plot=model.fit(X_train,y_train,epochs=15, validation_split=0.2)

#evaluating the model for testing data..
test_loss,test_acc=model.evaluate(X_test,y_test)
print("Test accuracy:",test_acc)
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 2.5502 - accuracy: 0.1941 - val_loss: 1.9263 - val_accuracy: 0.2854
# Epoch 2/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.8332 - accuracy: 0.3408 - val_loss: 1.7545 - val_accuracy: 0.3776
# Epoch 3/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.6990 - accuracy: 0.3873 - val_loss: 1.6653 - val_accuracy: 0.4128
# Epoch 4/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.6424 - accuracy: 0.4074 - val_loss: 1.6801 - val_accuracy: 0.3973
# Epoch 5/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.5955 - accuracy: 0.4263 - val_loss: 1.6499 - val_accuracy: 0.4078
# Epoch 6/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.5466 - accuracy: 0.4456 - val_loss: 1.6238 - val_accuracy: 0.4198
# Epoch 7/15
# ...

# %%
plotloss(plot)

# %%
plotacc(plot)

# %% [markdown]
# #  SOFTPLUS

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(32,32,3)),
    tf.keras.layers.Dense(128,activation='softplus'),
    tf.keras.layers.Dense(128,activation='softplus'),
    tf.keras.layers.Dense(128,activation='softplus'),
    tf.keras.layers.Dense(128,activation='softplus'),
    tf.keras.layers.Dense(10,activation='sigmoid')
])
#compiling the model...
model.compile(loss='sparse_categorical_crossentropy',metrics=['accuracy'])

#training data to the model...
plot=model.fit(X_train,y_train,epochs=15, validation_split=0.2)

#evaluating the model for testing data..
test_loss,test_acc=model.evaluate(X_test,y_test)
print("Test accuracy:",test_acc)
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 2.0712 - accuracy: 0.2449 - val_loss: 1.7774 - val_accuracy: 0.3732
# Epoch 2/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.7296 - accuracy: 0.3820 - val_loss: 1.6516 - val_accuracy: 0.4218
# Epoch 3/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.6320 - accuracy: 0.4205 - val_loss: 1.6170 - val_accuracy: 0.4315
# Epoch 4/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.6079 - accuracy: 0.4259 - val_loss: 1.6889 - val_accuracy: 0.4057
# Epoch 5/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.5726 - accuracy: 0.4443 - val_loss: 1.5894 - val_accuracy: 0.4409
# Epoch 6/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.5593 - accuracy: 0.4489 - val_loss: 1.6150 - val_accuracy: 0.4398
# Epoch 7/15
# ...

# %%
plotloss(plot)

# %%
plotacc(plot)

# %% [markdown]
# # ELU

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(32,32,3)),
    tf.keras.layers.Dense(128,activation='elu'),
    tf.keras.layers.Dense(128,activation='elu'),
    tf.keras.layers.Dense(128,activation='elu'),
    tf.keras.layers.Dense(128,activation='elu'),
    tf.keras.layers.Dense(10,activation='sigmoid')
])
#compiling the model...
model.compile(loss='sparse_categorical_crossentropy',metrics=['accuracy'])

#training data to the model...
plot=model.fit(X_train,y_train,epochs=15, validation_split=0.2)

#evaluating the model for testing data..
test_loss,test_acc=model.evaluate(X_test,y_test)
print("Test accuracy:",test_acc)
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 2.1547 - accuracy: 0.2303 - val_loss: 1.8456 - val_accuracy: 0.3327
# Epoch 2/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.7589 - accuracy: 0.3656 - val_loss: 1.7064 - val_accuracy: 0.3767
# Epoch 3/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.6441 - accuracy: 0.4085 - val_loss: 1.6177 - val_accuracy: 0.4167
# Epoch 4/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.5921 - accuracy: 0.4275 - val_loss: 1.5771 - val_accuracy: 0.4425
# Epoch 5/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.5315 - accuracy: 0.4540 - val_loss: 1.5538 - val_accuracy: 0.4514
# Epoch 6/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.4954 - accuracy: 0.4630 - val_loss: 1.6022 - val_accuracy: 0.4552
# Epoch 7/15
# ...

# %%
plotloss(plot)

# %%
plotacc(plot)

# %% [markdown]
# # RELU

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(32,32,3)),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(10,activation='sigmoid')
])
#compiling the model...
model.compile(loss='sparse_categorical_crossentropy',metrics=['accuracy'])

#training data to the model...
plot=model.fit(X_train,y_train,epochs=15, validation_split=0.2)

#evaluating the model for testing data..
test_loss,test_acc=model.evaluate(X_test,y_test)
print("Test accuracy:",test_acc)
plotloss(plot)
plotacc(plot)
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 2.0708 - accuracy: 0.2400 - val_loss: 1.9993 - val_accuracy: 0.2731
# Epoch 2/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7646 - accuracy: 0.3635 - val_loss: 1.8117 - val_accuracy: 0.3477
# Epoch 3/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.6953 - accuracy: 0.3919 - val_loss: 1.6733 - val_accuracy: 0.4054
# Epoch 4/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.6535 - accuracy: 0.4065 - val_loss: 1.7085 - val_accuracy: 0.4000
# Epoch 5/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.6127 - accuracy: 0.4230 - val_loss: 1.7929 - val_accuracy: 0.3663
# Epoch 6/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.5961 - accuracy: 0.4282 - val_loss: 1.6556 - val_accuracy: 0.4054
# Epoch 7/15
# ...

# %% [markdown]
# - From the above activation functions **ELU  and SELU Activation Function** is giving better accurancy socre

# %% [markdown]
# # **Experiment3:** Use different optimisers (Gradient Descent,Stochastic Gradient Descent, Mini-Batch Gradient Descent, Momentum Based Gradient Descent, Nesterov Accelerated Gradient, Adagrad, RMSProp, Adam)

# %% [markdown]
# # Using Different Optimisers

# %% [markdown]
# # **Gradient Descent**

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(32,32,3)),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(10,activation='sigmoid')
])
#compiling the model...

from keras.optimizers import SGD
sgd = SGD(momentum=0.0,name='SGD') # when  Momentum=0 then it is Gradient descent optimizer

model.compile(optimizer=sgd,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
#training data to the model...
plot=model.fit(X_train,y_train,epochs=15, validation_split=0.2)

#evaluating the model for testing data..
test_loss,test_acc=model.evaluate(X_test,y_test)
print("Test accuracy:",test_acc)
plotloss(plot)
plotacc(plot)
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 2.0938 - accuracy: 0.2290 - val_loss: 1.8369 - val_accuracy: 0.3378
# Epoch 2/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.7899 - accuracy: 0.3559 - val_loss: 1.7371 - val_accuracy: 0.3824
# Epoch 3/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.7024 - accuracy: 0.3908 - val_loss: 1.7131 - val_accuracy: 0.3875
# Epoch 4/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.6403 - accuracy: 0.4122 - val_loss: 1.7622 - val_accuracy: 0.3643
# Epoch 5/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.5932 - accuracy: 0.4353 - val_loss: 1.6813 - val_accuracy: 0.4023
# Epoch 6/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.5436 - accuracy: 0.4512 - val_loss: 1.7626 - val_accuracy: 0.3842
# Epoch 7/15
# ...

# %% [markdown]
# # **Stochastic Gradient Descent**

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(32,32,3)),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(10,activation='sigmoid')
])
#compiling the model...

model.compile(optimizer='SGD', loss='sparse_categorical_crossentropy',metrics=['accuracy'])

#training data to the model...
plot=model.fit(X_train,y_train,epochs=15, validation_split=0.2)

#evaluating the model for testing data..
test_loss,test_acc=model.evaluate(X_test,y_test)
print("Test accuracy:",test_acc)
plotloss(plot)
plotacc(plot)
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 2.0947 - accuracy: 0.2256 - val_loss: 1.8402 - val_accuracy: 0.3423
# Epoch 2/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.7881 - accuracy: 0.3554 - val_loss: 1.6990 - val_accuracy: 0.3871
# Epoch 3/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.6815 - accuracy: 0.3966 - val_loss: 1.6751 - val_accuracy: 0.3986
# Epoch 4/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.6158 - accuracy: 0.4218 - val_loss: 1.6887 - val_accuracy: 0.3998
# Epoch 5/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.5693 - accuracy: 0.4405 - val_loss: 1.6763 - val_accuracy: 0.4177
# Epoch 6/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.5315 - accuracy: 0.4530 - val_loss: 1.5599 - val_accuracy: 0.4445
# Epoch 7/15
# ...

# %% [markdown]
# # **Mini-Batch Gradient Descent**

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(32,32,3)),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(10,activation='sigmoid')
])
#compiling the model...

#from keras.optimizers import SGD
#sgd = SGD(momentum=0.9,name='SGD')

model.compile(optimizer="SGD",
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
#training data to the model...
plot=model.fit(X_train,y_train,epochs=15,batch_size=20, validation_split=0.2)

#evaluating the model for testing data..
test_loss,test_acc=model.evaluate(X_test,y_test)
print("Test accuracy:",test_acc)
plotloss(plot)
plotacc(plot)
# Out:
# Epoch 1/15
# 2000/2000 [==============================] - 5s 2ms/step - loss: 2.0514 - accuracy: 0.2462 - val_loss: 1.7877 - val_accuracy: 0.3548
# Epoch 2/15
# 2000/2000 [==============================] - 4s 2ms/step - loss: 1.7479 - accuracy: 0.3719 - val_loss: 1.6869 - val_accuracy: 0.3931
# Epoch 3/15
# 2000/2000 [==============================] - 4s 2ms/step - loss: 1.6629 - accuracy: 0.4004 - val_loss: 1.6453 - val_accuracy: 0.4098
# Epoch 4/15
# 2000/2000 [==============================] - 4s 2ms/step - loss: 1.5852 - accuracy: 0.4360 - val_loss: 1.5971 - val_accuracy: 0.4313
# Epoch 5/15
# 2000/2000 [==============================] - 4s 2ms/step - loss: 1.5525 - accuracy: 0.4456 - val_loss: 1.5884 - val_accuracy: 0.4389
# Epoch 6/15
# 2000/2000 [==============================] - 4s 2ms/step - loss: 1.5005 - accuracy: 0.4596 - val_loss: 1.5267 - val_accuracy: 0.4536
# Epoch 7/15
# ...

# %% [markdown]
# # **Momentum Based Gradient Descent**

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(32,32,3)),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(10,activation='sigmoid')
])
#compiling the model...

from keras.optimizers import SGD
sgd = SGD(momentum=0.9,name='SGD')

model.compile(optimizer=sgd,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
#training data to the model...
plot=model.fit(X_train,y_train,epochs=15, validation_split=0.2)

#evaluating the model for testing data..
test_loss,test_acc=model.evaluate(X_test,y_test)
print("Test accuracy:",test_acc)
plotloss(plot)
plotacc(plot)
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 6s 2ms/step - loss: 2.0178 - accuracy: 0.2486 - val_loss: 1.7934 - val_accuracy: 0.3510
# Epoch 2/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.7912 - accuracy: 0.3518 - val_loss: 1.7339 - val_accuracy: 0.3777
# Epoch 3/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.7028 - accuracy: 0.3854 - val_loss: 1.7387 - val_accuracy: 0.3832
# Epoch 4/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.6494 - accuracy: 0.4056 - val_loss: 1.6858 - val_accuracy: 0.3891
# Epoch 5/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.6106 - accuracy: 0.4217 - val_loss: 1.6215 - val_accuracy: 0.4235
# Epoch 6/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.5723 - accuracy: 0.4337 - val_loss: 1.5805 - val_accuracy: 0.4320
# Epoch 7/15
# ...

# %% [markdown]
# # **Nesterov Accelerated Gradient**

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(32,32,3)),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(10,activation='sigmoid')
])
#compiling the model...
from keras.optimizers import SGD
sgd = SGD(nesterov=True)

model.compile(optimizer=sgd,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

#training data to the model...
plot=model.fit(X_train,y_train,epochs=15, validation_split=0.2)

#evaluating the model for testing data..
test_loss,test_acc=model.evaluate(X_test,y_test)
print("Test accuracy:",test_acc)
plotloss(plot)
plotacc(plot)
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 2.1002 - accuracy: 0.2251 - val_loss: 1.8560 - val_accuracy: 0.3388
# Epoch 2/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.7902 - accuracy: 0.3582 - val_loss: 1.7372 - val_accuracy: 0.3785
# Epoch 3/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.6967 - accuracy: 0.3935 - val_loss: 1.6903 - val_accuracy: 0.3903
# Epoch 4/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.6275 - accuracy: 0.4188 - val_loss: 1.6004 - val_accuracy: 0.4339
# Epoch 5/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.5792 - accuracy: 0.4386 - val_loss: 1.6339 - val_accuracy: 0.4111
# Epoch 6/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.5310 - accuracy: 0.4507 - val_loss: 1.5951 - val_accuracy: 0.4354
# Epoch 7/15
# ...

# %% [markdown]
# # **Adagrad**

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(32,32,3)),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(10,activation='sigmoid')
])
#compiling the model...

model.compile(optimizer='Adagrad', loss='sparse_categorical_crossentropy',metrics=['accuracy'])

#training data to the model...
plot=model.fit(X_train,y_train,epochs=15, validation_split=0.2)

#evaluating the model for testing data..
test_loss,test_acc=model.evaluate(X_test,y_test)
print("Test accuracy:",test_acc)
plotloss(plot)
plotacc(plot)
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 2.2060 - accuracy: 0.1950 - val_loss: 1.9700 - val_accuracy: 0.2894
# Epoch 2/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.9269 - accuracy: 0.3054 - val_loss: 1.8832 - val_accuracy: 0.3361
# Epoch 3/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.8458 - accuracy: 0.3437 - val_loss: 1.8228 - val_accuracy: 0.3569
# Epoch 4/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.7905 - accuracy: 0.3650 - val_loss: 1.7935 - val_accuracy: 0.3684
# Epoch 5/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.7567 - accuracy: 0.3800 - val_loss: 1.7755 - val_accuracy: 0.3747
# Epoch 6/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.7374 - accuracy: 0.3809 - val_loss: 1.7544 - val_accuracy: 0.3818
# Epoch 7/15
# ...

# %% [markdown]
# # **RMSProp**

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(32,32,3)),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(10,activation='sigmoid')
])
#compiling the model...

model.compile(optimizer='RMSprop', loss='sparse_categorical_crossentropy',metrics=['accuracy'])

#training data to the model...
plot=model.fit(X_train,y_train,epochs=15, validation_split=0.2)

#evaluating the model for testing data..
test_loss,test_acc=model.evaluate(X_test,y_test)
print("Test accuracy:",test_acc)
plotloss(plot)
plotacc(plot)
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 2.0729 - accuracy: 0.2340 - val_loss: 1.7692 - val_accuracy: 0.3585
# Epoch 2/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.7701 - accuracy: 0.3618 - val_loss: 1.7383 - val_accuracy: 0.3800
# Epoch 3/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.6922 - accuracy: 0.3921 - val_loss: 1.7188 - val_accuracy: 0.3842
# Epoch 4/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.6451 - accuracy: 0.4117 - val_loss: 1.6201 - val_accuracy: 0.4177
# Epoch 5/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.6057 - accuracy: 0.4284 - val_loss: 1.6396 - val_accuracy: 0.4270
# Epoch 6/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.5885 - accuracy: 0.4313 - val_loss: 1.6841 - val_accuracy: 0.4111
# Epoch 7/15
# ...

# %% [markdown]
# # **Adam**

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(32,32,3)),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(10,activation='sigmoid')
])
#compiling the model...

model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy',metrics=['accuracy'])

#training data to the model...
plot=model.fit(X_train,y_train,epochs=15, validation_split=0.2)

#evaluating the model for testing data..
test_loss,test_acc=model.evaluate(X_test,y_test)
print("Test accuracy:",test_acc)
plotloss(plot)
plotacc(plot)
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 2.0169 - accuracy: 0.2557 - val_loss: 1.8028 - val_accuracy: 0.3447
# Epoch 2/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.7274 - accuracy: 0.3744 - val_loss: 1.6791 - val_accuracy: 0.3896
# Epoch 3/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.6536 - accuracy: 0.4061 - val_loss: 1.6352 - val_accuracy: 0.4138
# Epoch 4/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.5960 - accuracy: 0.4247 - val_loss: 1.6371 - val_accuracy: 0.4122
# Epoch 5/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.5496 - accuracy: 0.4422 - val_loss: 1.5848 - val_accuracy: 0.4247
# Epoch 6/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.5266 - accuracy: 0.4473 - val_loss: 1.5700 - val_accuracy: 0.4394
# Epoch 7/15
# ...

# %% [markdown]
# # **Experiment4:** Add Dropout and Batch Normalisation

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(32,32,3)),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dropout(rate=0.3,seed=71),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(10,activation='sigmoid')
])
#compiling the model...

model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy',metrics=['accuracy'])

#training data to the model...
plot=model.fit(X_train,y_train,epochs=55, validation_split=0.2)

#evaluating the model for testing data..
test_loss,test_acc=model.evaluate(X_test,y_test)
print("Test accuracy:",test_acc)
plotloss(plot)
plotacc(plot)
# Out:
# Epoch 1/55
# 1250/1250 [==============================] - 4s 3ms/step - loss: 2.1722 - accuracy: 0.2128 - val_loss: 1.9878 - val_accuracy: 0.2801
# Epoch 2/55
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.8599 - accuracy: 0.3260 - val_loss: 1.9102 - val_accuracy: 0.3207
# Epoch 3/55
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.7612 - accuracy: 0.3638 - val_loss: 1.7024 - val_accuracy: 0.3892
# Epoch 4/55
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.7056 - accuracy: 0.3842 - val_loss: 1.6490 - val_accuracy: 0.4021
# Epoch 5/55
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.6624 - accuracy: 0.4012 - val_loss: 1.7373 - val_accuracy: 0.3736
# Epoch 6/55
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.6485 - accuracy: 0.4091 - val_loss: 1.6663 - val_accuracy: 0.4079
# Epoch 7/55
# ...
